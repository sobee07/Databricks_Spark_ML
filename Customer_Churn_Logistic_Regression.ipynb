# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
file_location = "/FileStore/tables/customer_churn.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Names</th><th>Age</th><th>Total_Purchase</th><th>Account_Manager</th><th>Years</th><th>Num_Sites</th><th>Onboard_date</th><th>Location</th><th>Company</th><th>Churn</th></tr></thead><tbody><tr><td>Cameron Williams</td><td>42.0</td><td>11066.8</td><td>0</td><td>7.22</td><td>8.0</td><td>2013-08-30T07:00:40.000+0000</td><td>10265 Elizabeth Mission Barkerburgh, AK 89518</td><td>Harvey LLC</td><td>1</td></tr><tr><td>Kevin Mueller</td><td>41.0</td><td>11916.22</td><td>0</td><td>6.5</td><td>11.0</td><td>2013-08-13T00:38:46.000+0000</td><td>6157 Frank Gardens Suite 019 Carloshaven, RI 17756</td><td>Wilson PLC</td><td>1</td></tr><tr><td>Eric Lozano</td><td>38.0</td><td>12884.75</td><td>0</td><td>6.67</td><td>12.0</td><td>2016-06-29T06:20:07.000+0000</td><td>1331 Keith Court Alyssahaven, DE 90114</td><td>Miller, Johnson and Wallace</td><td>1</td></tr><tr><td>Phillip White</td><td>42.0</td><td>8010.76</td><td>0</td><td>6.71</td><td>10.0</td><td>2014-04-22T12:43:12.000+0000</td><td>13120 Daniel Mount Angelabury, WY 30645-4695</td><td>Smith Inc</td><td>1</td></tr><tr><td>Cynthia Norton</td><td>37.0</td><td>9191.58</td><td>0</td><td>5.56</td><td>9.0</td><td>2016-01-19T15:31:15.000+0000</td><td>765 Tricia Row Karenshire, MH 71730</td><td>Love-Jones</td><td>1</td></tr><tr><td>Jessica Williams</td><td>48.0</td><td>10356.02</td><td>0</td><td>5.12</td><td>8.0</td><td>2009-03-03T23:13:37.000+0000</td><td>6187 Olson Mountains East Vincentborough, PR 74359</td><td>Kelly-Warren</td><td>1</td></tr><tr><td>Eric Butler</td><td>44.0</td><td>11331.58</td><td>1</td><td>5.23</td><td>11.0</td><td>2016-12-05T03:35:43.000+0000</td><td>4846 Savannah Road West Justin, IA 87713-3460</td><td>Reynolds-Sheppard</td><td>1</td></tr><tr><td>Zachary Walsh</td><td>32.0</td><td>9885.12</td><td>1</td><td>6.92</td><td>9.0</td><td>2006-03-09T14:50:20.000+0000</td><td>25271 Roy Expressway Suite 147 Brownport, FM 59852-6150</td><td>Singh-Cole</td><td>1</td></tr><tr><td>Ashlee Carr</td><td>43.0</td><td>14062.6</td><td>1</td><td>5.46</td><td>11.0</td><td>2011-09-29T05:47:23.000+0000</td><td>3725 Caroline Stravenue South Christineview, MA 82059</td><td>Lopez PLC</td><td>1</td></tr><tr><td
# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "customer_churn_csv"

# df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.schema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: StructType(List(StructField(Names,StringType,true),StructField(Age,DoubleType,true),StructField(Total_Purchase,DoubleType,true),StructField(Account_Manager,IntegerType,true),StructField(Years,DoubleType,true),StructField(Num_Sites,DoubleType,true),StructField(Onboard_date,TimestampType,true),StructField(Location,StringType,true),StructField(Company,StringType,true),StructField(Churn,IntegerType,true)))</div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [&#39;Names&#39;,
#  &#39;Age&#39;,
#  &#39;Total_Purchase&#39;,
#  &#39;Account_Manager&#39;,
#  &#39;Years&#39;,
#  &#39;Num_Sites&#39;,
#  &#39;Onboard_date&#39;,
#  &#39;Location&#39;,
#  &#39;Company&#39;,
#  &#39;Churn&#39;]</div>

# %%
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------+-----------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+-------------------+
# summary|        Names|              Age|   Total_Purchase|   Account_Manager|            Years|         Num_Sites|            Location|             Company|              Churn|
# +-------+-------------+-----------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+-------------------+
#   count|          900|              900|              900|               900|              900|               900|                 900|                 900|                900|
#    mean|         null|41.81666666666667|10062.82403333334|0.4811111111111111| 5.27315555555555| 8.587777777777777|                null|                null|0.16666666666666666|
#  stddev|         null|6.127560416916251|2408.644531858096|0.4999208935073339|1.274449013194616|1.7648355920350969|                null|                null| 0.3728852122772358|
#     min|   Aaron King|             22.0|            100.0|                 0|              1.0|               3.0|00103 Jeffrey Cre...|     Abbott-Thompson|                  0|
#     max|Zachary Walsh|             65.0|         18026.01|                 1|             9.15|              14.0|Unit 9800 Box 287...|Zuniga, Clark and...|                  1|
# +-------+-------------+-----------------+-----------------+------------------+-----------------+------------------+--------------------+--------------------+-------------------+
#
# </div>

# %%
from pyspark.ml.classification import LogisticRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.feature import VectorAssembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vector=VectorAssembler(inputCols=['Age',
 'Total_Purchase',
  'Account_Manager',
   'Years',
 'Num_Sites'
  ],outputCol='features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output=vector.transform(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_data=output.select(['features','churn'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_data.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: [Row(features=DenseVector([42.0, 11066.8, 0.0, 7.22, 8.0]), churn=1),
#  Row(features=DenseVector([41.0, 11916.22, 0.0, 6.5, 11.0]), churn=1),
#  Row(features=DenseVector([38.0, 12884.75, 0.0, 6.67, 12.0]), churn=1)]</div>

# %%
train_data,test_data=final_data.randomSplit([0.7,0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr=LogisticRegression(labelCol='churn')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr_fit=lr.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_summ=lr_fit.summary
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_summ.areaUnderROC
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 0.8978153629316414</div>

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pred_label=lr_fit.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pred_label.predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+--------------------+--------------------+----------+
#             features|churn|       rawPrediction|         probability|prediction|
# +--------------------+-----+--------------------+--------------------+----------+
# [26.0,8787.39,1.0...|    1|[0.54312986665542...|[0.63254020364354...|       0.0|
# [29.0,11274.46,1....|    0|[4.25521071025116...|[0.98600844119372...|       0.0|
# [30.0,8677.28,1.0...|    0|[3.61327816307276...|[0.97374462029027...|       0.0|
# [30.0,10183.98,1....|    0|[2.68555027620801...|[0.93616859522148...|       0.0|
# [31.0,7073.61,0.0...|    0|[2.70473042231065...|[0.93730519896068...|       0.0|
# [31.0,8688.21,0.0...|    0|[6.18255738499988...|[0.99793911627461...|       0.0|
# [31.0,9574.89,0.0...|    0|[2.80756227373989...|[0.94308310973237...|       0.0|
# [31.0,10182.6,1.0...|    0|[4.55907720506278...|[0.98963680274219...|       0.0|
# [31.0,11297.57,1....|    1|[0.85670503205938...|[0.70197178173228...|       0.0|
# [31.0,12264.68,1....|    0|[3.26280326887029...|[0.96313046460446...|       0.0|
# [32.0,7896.65,0.0...|    0|[2.90937419510136...|[0.94830789616397...|       0.0|
# [32.0,8575.71,0.0...|    0|[3.51238168715154...|[0.97103801998490...|       0.0|
# [32.0,11715.72,0....|    0|[3.18598772761476...|[0.96030355222076...|       0.0|
# [32.0,12142.99,0....|    0|[5.22138741855835...|[0.99462916948340...|       0.0|
# [32.0,12403.6,0.0...|    0|[5.22973034228472...|[0.99467355383797...|       0.0|
# [33.0,7492.9,0.0,...|    0|[4.21211496438819...|[0.98540127811480...|       0.0|
# [33.0,10306.21,1....|    0|[1.78956042544598...|[0.85687337494027...|       0.0|
# [33.0,12115.91,1....|    0|[2.28050103967040...|[0.90724921701057...|       0.0|
# [33.0,13157.08,1....|    0|[1.43729695981985...|[0.80803572114913...|       0.0|
# [33.0,13314.19,0....|    0|[2.67726373644874...|[0.93567162344978...|       0.0|
# +--------------------+-----+--------------------+--------------------+----------+
# only showing top 20 rows
#
# </div>

# %%
churn_eval=BinaryClassificationEvaluator(rawPredictionCol='prediction',labelCol='churn')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
auc=churn_eval.evaluate(pred_label.predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
auc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: 0.7661324786324786</div>

# %%
final_lr_model=lr.fit(final_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
 new_data=spark.read.csv("/FileStore/tables/new_customers.csv",inferSchema=True,header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_data.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: [Row(Names=&#39;Andrew Mccall&#39;, Age=37.0, Total_Purchase=9935.53, Account_Manager=1, Years=7.71, Num_Sites=8.0, Onboard_date=datetime.datetime(2011, 8, 29, 18, 37, 54), Location=&#39;38612 Johnny Stravenue Nataliebury, WI 15717-8316&#39;, Company=&#39;King Ltd&#39;),
#  Row(Names=&#39;Michele Wright&#39;, Age=23.0, Total_Purchase=7526.94, Account_Manager=1, Years=9.28, Num_Sites=15.0, Onboard_date=datetime.datetime(2013, 7, 22, 18, 19, 54), Location=&#39;21083 Nicole Junction Suite 332, Youngport, ME 23686-4381&#39;, Company=&#39;Cannon-Benson&#39;),
#  Row(Names=&#39;Jeremy Chang&#39;, Age=65.0, Total_Purchase=100.0, Account_Manager=1, Years=1.0, Num_Sites=15.0, Onboard_date=datetime.datetime(2006, 12, 11, 7, 48, 13), Location=&#39;085 Austin Views Lake Julialand, WY 63726-4298&#39;, Company=&#39;Barron-Robertson&#39;),
#  Row(Names=&#39;Megan Ferguson&#39;, Age=32.0, Total_Purchase=6487.5, Account_Manager=0, Years=9.4, Num_Sites=14.0, Onboard_date=datetime.datetime(2016, 10, 28, 5, 32, 13), Location=&#39;922 Wright Branch North Cynthialand, NC 64721&#39;, Company=&#39;Sexton-Golden&#39;),
#  Row(Names=&#39;Taylor Young&#39;, Age=32.0, Total_Purchase=13147.71, Account_Manager=1, Years=10.0, Num_Sites=8.0, Onboard_date=datetime.datetime(2012, 3, 20, 0, 36, 46), Location=&#39;Unit 0789 Box 0734 DPO AP 39702&#39;, Company=&#39;Wood LLC&#39;)]</div>

# %%
test_new_data=vector.transform(new_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_new_data.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: [Row(Names=&#39;Andrew Mccall&#39;, Age=37.0, Total_Purchase=9935.53, Account_Manager=1, Years=7.71, Num_Sites=8.0, Onboard_date=datetime.datetime(2011, 8, 29, 18, 37, 54), Location=&#39;38612 Johnny Stravenue Nataliebury, WI 15717-8316&#39;, Company=&#39;King Ltd&#39;, features=DenseVector([37.0, 9935.53, 1.0, 7.71, 8.0])),
#  Row(Names=&#39;Michele Wright&#39;, Age=23.0, Total_Purchase=7526.94, Account_Manager=1, Years=9.28, Num_Sites=15.0, Onboard_date=datetime.datetime(2013, 7, 22, 18, 19, 54), Location=&#39;21083 Nicole Junction Suite 332, Youngport, ME 23686-4381&#39;, Company=&#39;Cannon-Benson&#39;, features=DenseVector([23.0, 7526.94, 1.0, 9.28, 15.0])),
#  Row(Names=&#39;Jeremy Chang&#39;, Age=65.0, Total_Purchase=100.0, Account_Manager=1, Years=1.0, Num_Sites=15.0, Onboard_date=datetime.datetime(2006, 12, 11, 7, 48, 13), Location=&#39;085 Austin Views Lake Julialand, WY 63726-4298&#39;, Company=&#39;Barron-Robertson&#39;, features=DenseVector([65.0, 100.0, 1.0, 1.0, 15.0]))]</div>

# %%
final_result=lr_fit.transform(test_new_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_result.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: [Row(Names=&#39;Andrew Mccall&#39;, Age=37.0, Total_Purchase=9935.53, Account_Manager=1, Years=7.71, Num_Sites=8.0, Onboard_date=datetime.datetime(2011, 8, 29, 18, 37, 54), Location=&#39;38612 Johnny Stravenue Nataliebury, WI 15717-8316&#39;, Company=&#39;King Ltd&#39;, features=DenseVector([37.0, 9935.53, 1.0, 7.71, 8.0]), rawPrediction=DenseVector([1.8733, -1.8733]), probability=DenseVector([0.8668, 0.1332]), prediction=0.0),
#  Row(Names=&#39;Michele Wright&#39;, Age=23.0, Total_Purchase=7526.94, Account_Manager=1, Years=9.28, Num_Sites=15.0, Onboard_date=datetime.datetime(2013, 7, 22, 18, 19, 54), Location=&#39;21083 Nicole Junction Suite 332, Youngport, ME 23686-4381&#39;, Company=&#39;Cannon-Benson&#39;, features=DenseVector([23.0, 7526.94, 1.0, 9.28, 15.0]), rawPrediction=DenseVector([-6.0143, 6.0143]), probability=DenseVector([0.0024, 0.9976]), prediction=1.0)]</div>

# %%
final_result.select(['Company','prediction']).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------+----------+
#          Company|prediction|
# +----------------+----------+
#         King Ltd|       0.0|
#    Cannon-Benson|       1.0|
# Barron-Robertson|       1.0|
#    Sexton-Golden|       1.0|
#         Wood LLC|       0.0|
#    Parks-Robbins|       1.0|
# +----------------+----------+
#
# </div>
